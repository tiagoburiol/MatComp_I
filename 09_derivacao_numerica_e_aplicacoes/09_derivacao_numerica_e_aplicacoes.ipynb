# %% [markdown]
# ### 9. Derivação numérica e aplicações
#
# ### 9.1 Introdução
#
# Muitos sistemas estudados em ciência e engenharia variam no espaço, no tempo ou em função de alguma outra variável. Na matemática, as derivadas são usadas para modelar e descrever essas mudanças. A derivada de uma função representa da taxa de variação de uma variável dependente em relação a uma variável independente. A partir do cálculo, muitas fórmulas e métodos para derivar funções podem ser desenvolvidos. Porém, em em alguns casos, a função de interesse pode não ter sua expressão analítica conhecida, ser difícil de manejar, ou ainda, ser expressa por por meio de um conjunto discreto de pontos. Nesses e em outros casos é conveniente obter derivadas numericamente ao invés de analiticamente. Neste capítulo vamos estudar diferentes formas de se obter aproximações numéricas para as derivadas de uma função.

# %% [markdown]
# A derivada de uma função $f(x)$ no ponto $x=p$ é definida como:
#
# $$f'(p) = \lim\limits_{x \to p}\frac{f(x) - f(p)}{x-p}$$
#
# A derivada de 1ª ordem em $x=p$ é a inclinação da reta tangente à função neste ponto, ou simplesmente, a inclinação da função. Assim, a derivada informa sobre a taxa de variação instantânea da função $y=f(x)$ em relação à variação de $x$ no ponto quando $x=p$.
#
# Além disso, tomando $p$ suficientemente próximo de $x$ podemos facilmente inferir que uma boa aproximação para o valor da derivada 1ª de $f$ em $x$ será dada por
#
# $$f'(p) \approx \frac{f(x) - f(p)}{x-p}$$
#
# Essa fórmula fornece um valor aproximado para a inclinação da reta tangente usando a inclinação da reta secante à $f$ que intercepta o gráfico nos pontos $(x,f(x))$ e $(p, f(p))$.

# %% [markdown]
# <img src="https://github.com/tiagoburiol/MatComp_I/blob/main/09_derivacao_numerica_e_aplicacoes/figuras/derivada.png?raw=true" width="400">
#
# Figura 9.1 - Interpretação geométrica da derivada

# %% [markdown]
# Podemos concluir facilmente que quanto mais próximo o ponto $p$ estiver de $x$, mais próxima a inclinação da reta secante estará da reta tangente. Em outras palavras, quanto menor o valor de $h=x-p$ melhor a aproximação obtida.

# %% [markdown]
# Obter numericamente aproximações para a derivada de uma função muitas vezes requer discretizar uma região do domínio, o que significa, tomar um conjunto finito de pontos chamado de malha ou _grid_. No caso de uma função de uma variável $y=f(x)$, podemos tomar $n+1$ pontos $x_i$, $i=0,1,...,n$ no intervalo $[x_0,x_n]$ como mostra a figura abaixo.
#
# <img src="https://github.com/tiagoburiol/MatComp_I/blob/main/09_derivacao_numerica_e_aplicacoes/figuras/grid.png?raw=true" width="500">
# Figura 9.2 - Discretização de um intervalo do domínio da função

# %% [markdown]
# Mesmo para uma função contínua com expressão conhecida a representação discretizada é útil para cálculos numéricos. Além disso, em  muitos casos o valor da função é conhecido apenas em um conjunto finito de pontos. Por exemplo, ao tratar com dados proveniente de sensores que  fazem medições de variáveis físicas (como temperatura, pressão, etc) em intervalos de tempo regulares.
#
# No exemplo a seguir vamos usar uma expressão para a derivada numérica e obter o valor da derivada para um conjunto discreto de pontos, fazer o gráfico e comparar com o gráfico da função derivada obtida analiticamente.

# %% [markdown]
# **Exemplo 9.1:**
# Sabemos que a derivada primeira de $f(x)=sen(x)$ é $f'(x)=cos(x)$. Vamos calcular as derivadas numericamente e comparar os gráficos para alguns valores de $x$ dividindo o um intervalo em 20 e 40 subintervalos e vamos plotar os resultados.

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(4,3)

# %% [markdown]
# Dado um conjunto de pontos $x_i$, com $i=0,1,2,...,n$, as diferenças $x_{i+1}-x_i$, com $i=0,1,2,...,n-1$, podem ser obtidas operando o _array_ fazendo `x[1:n]-x[0:n-1]`, como é mostrado no exemplo abaixo

# %%
x = np.array([0,1,3,5,8])
n=len(x)
print(x[1:n]-x[0:n-1])
# Out:
# [1 2 2 3]

# %% [markdown]
# Mas também podemos usar a função `numpy.diff`, que produz o mesmo resultado, como podemos verificar a seguir

# %%
print(np.diff(x))
# Out:
# [1 2 2 3]

# %% [markdown]
# Agora vamos calcular as derivadas numéricamente fazendo $f'(x_i)\approx \frac{f(x_{i+1})-f(x_i)}{x_{i+1}-x_i}$  para $i=0,1,2,...,n-1$ com $n=20$ e $n=40$, e então, plotar os gráficos

# %%
# Derivadas numéricas em 20 pontos 
xi20 = np.linspace(0, 2*np.pi, 21)
dxi20 = np.diff(np.sin(xi20))/np.diff(xi20)

# Derivadas numéricas em 40 pontos 
xi40 = np.linspace(0, 2*np.pi, 41)
dxi40 = np.diff(np.sin(xi40))/np.diff(xi40)

# Pontos para o gráfico de cos(x)
xplot = np.linspace(0, 6)

plt.plot(xplot,np.cos(xplot),'-k',label='Analítica',lw=1)
plt.plot(xi20[0:-1],dxi20,'--k',label='20 pontos',lw=1)
plt.plot(xi40[0:-1],dxi40, '-.k',label='40 pontos',lw=1)

plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# É possível observar que a curva obtida para a derivada numérica usando 40 pontos é mais próxima da função analítica do que a aproximação obtida com 20 pontos.
#
# Também é possivel obter as derivadas por fórmulas mais precisas, utilizando, por exemplo, doi ou mais pontos da vizinhanca de $x_i$. A seguir vamos apresentar algumas dessas fórmulas e mais alguns exemplos computacionais.

# %% [markdown]
# #### 9.2 Derivada de 1ª ordem em uma variável
#
# A aproximação numérica para a derivada de 1ª ordem de uma função $y=f(x)$ em um ponto $x_i$ pode ser obtida por diferença finita, em que a inclinação da função é estimada usando valores da função na vizinhança do ponto.
#
# Chamamos aproximação _**para frente**_ quando se estima $f'(x_i)$ usando a inclinação da reta secante que passa pelos pontos $(x_i, f(x_i))$ e $(x_{i+1}, f(x_{i+1}))$. A aproximação _**para trás**_ é quando usamos a inclinação da reta que passa pelos pontos $(x_{i-1}, f(x_{i-1}))$ e $(x_{i}, f(x_{i}))$. E a aproximação _**central**_ é quando usamos a inclinação da reta que passa pelos pontos $(x_{i-1}, f(x_{i-1}))$ e $(x_{i+1}, f(x_{i+1}))$.
#
# A seguir são mostradas as fórmulas e uma representação geométrica  que ilustra a aproximação de $f'(x_i)$ _para frente_, _para trás_ e _central_ respectivamente:

# %% [markdown]
# $$f'(x_i) \approx \frac{f(x_{i+1}) - f(x_i)}{x_{i+1}-x_i} \quad \quad \quad \quad \quad
# f'(x_i) \approx \frac{f(x_{i}) - f(x_{i-1})}{x_i-x_{i-1}}  \quad \quad \quad \quad \quad
# f'(x_i) \approx \frac{f(x_{i+1}) - f(x_{i-1})}{x_{i+1}-x_{i-1}}$$
#
#
# <img src="https://github.com/tiagoburiol/MatComp_I/blob/main/09_derivacao_numerica_e_aplicacoes/figuras/diffs.png?raw=true" width="960">
# Figura 9.3 - Fórmulas de derivação numérica

# %% [markdown]
# As fórmulas de diferenças finitas mostradas acima podem ser obtidas a partir da série de Taylor para a função $f(x)$ desenvolvida em torno de $x=x_i$ o que nos fornece

# %% [markdown]
# $$f(x) = f(x_i) + f(x_i)(x - x_i) + f''(x_i)\frac{(x - x_i)^2}{2!} + f'''(x_i)\frac{(x - x_i)^3}{3!} + \cdots$$

# %% [markdown]
# Ao aproximarmos $x_{i+1}$ por $x_i$, se considerarmos $h=x_{i+1}-x_i$ suficientemente pequeno, podemos desprezar os termos de ordem mais alta, proporcionais a $(x_{i+1}-x_i)^2$, $(x_{i+1}-x_i)^3$,$ \dots$. Assim, a derivada de $f(x)$ em $x_i$ pode ser aproximada por
#
# $$f'(x_i) \approx \frac{f(x_{i+1}) - f(x_i)}{h} $$
#
# Que é exatamente a fórmula para a aproximação _para frente_ da derivada 1ª de $f$. Observe que nessa aproximação foram desprezados os termos
#
# $$ O(h^2) = \frac{f''(x_i)h^2}{2} + \frac{f'''(x_i)h^3}{6} + \frac{f''''(x_i)h^4}{24} + \frac{f'''''(x_i)h^5}{120} +\cdots$$
#
# o que mostra que o erro de truncamento depende de $h$. Quanto menor o _passo_ $h$ menor será o erro, no entanto maior será o esforço computacional, o que impossibilita o cálculo com valores de $h$ próximos de zero.

# %% [markdown]
# Em termos de $h$ as fórmulas de aproximação por diferenças finitas ficam com as segiuntes formas:
#
# - _Para frente_: $f'(x_i)\approx\frac{f(x_{i+1})-f(x_i)}{h}$
#
#
# - _Para trás_: $f'(x_i)\approx\frac{f(x_{i})-f(x_{i-1})}{h}$
#
#
# - _Central_: $f'(x_i)\approx\frac{f(x_{i+1})-f(x_{i-1})}{2h}$

# %% [markdown]
# **Exemplo 9.3:** Sabemos que a derivada primeira de $f(x)=sen(x)$ é $f'(x)=cos(x)$. Vamos calcular as derivadas numericamente usando as fórmulas de diferenças finitas _para frente_, _central_ e _para trás_ no intervalo $[0,2\pi]$ discretizado em 21 pontos.

# %%
xi = np.linspace(0, 2*np.pi, 21)
h=(xi[-1]-xi[0])/(len(xi)-1)
f = lambda x: np.sin(x)

dxit = (f(xi[1:])-f(xi[0:-1]))/h
dxic = (f(xi[2:])-f(xi[0:-2]))/(2*h)

xplot = np.linspace(0, 2*np.pi, 61)

plt.plot(xplot,np.cos(xplot),'-k',
         alpha=0.5,label='Analítica')
plt.plot(xi[1:],dxit,'--k',label='Para trás')
plt.plot(xi[1:-1],dxic,'-.k',label='Central')
plt.plot(xi[0:-1],dxit,':k',label='Para frente')

plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# É possível notar que a aproximação por diferenças finitas centrais produz um resultado mais preciso, no entanto, não se tem resultados nos extremos do intervalo.

# %% [markdown]
# Usando a função `numpy.gradinent` podemos obter as aproximações para as derivadas por diferencas finitas centrais nos pontos $x_1,x_2,...,x_{n-1}$ e nas extremidades $x_0$ e $x_n$ por diferenças finitas para frente e para trás, respectivamente. Assim, tem-se a aproximação para a derivada em todos os pontos $x_i$, $i=0,1,...,n$. O exemplo abaixo mostra o uso da função `numpy.gradient` para aproximar a derivada de $f(x) = sen(x)$, ou seja, obter uma aproximação para $f'(x)=cos(x)$.

# %%
plt.plot(xplot,np.cos(xplot),'-k',
         alpha=0.5,label='Analítica')
plt.plot(xi,np.gradient(f(xi),xi),':k',
         label='Aproximada')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# Observemos agora que desenvolvendo a série de Taylor em torno de $x_i$ para obter o valor da função nos pontos  da vizinhança de $x_i$, mostrados na figura 9.4
#
# <img src="https://raw.githubusercontent.com/tiagoburiol/MatComp_I/refs/heads/main/09_derivacao_numerica_e_aplicacoes/figuras/grid5pts.png" width="400"><br>
#   Figura 9.4 - Pontos $x_{i-2}$, $x_{i-1}$, $x_{i+1}$ e $x_{i+2}$, da vizinhança de $x_i$

# %% [markdown]
# obtemos as seguintes expressões:
#
# $f(x_{i-2})=f(x_i)-2hf^{(1)}(x_i)+\frac{4h^2f^{(2)}(x_i)}{2}-\frac{8h^3f^{(3)}(x_i)}{6}+\frac{16h^4f^{(4)}(x_i)}{24}-\frac{32h^5f^{(5)}(x_i)}{120}+\dots$
#
# $f(x_{i-1})=f(x_i)-hf^{(1)}(x_i)+\frac{h^2f^{(2)}(x_i)}{2}-\frac{h^3f^{(3)}(x_i)}{6}+\frac{h^4f^{(4)}(x_i)}{24}-\frac{h^5f^{(5)}(x_i)}{120}+\dots$
#
# $f(x_{i+1})=f(x_i)+hf^{(1)}(x_i)+\frac{h^2f^{(2)}(x_i)}{2}+\frac{h^3f^{(3)}(x_i)}{6} +\frac{h^4f^{(4)}(x_i)}{24}+\frac{h^5f^{(5)}(x_i)}{120}+\dots$
#
# $f(x_{i+2})=f(x_i)+2hf^{(1)}(x_i)+\frac{4h^2f^{(2)}(x_i)}{2}+\frac{8h^3f^{(3)}(x_i)}{6}+\frac{16h^4f^{(4)}(x_i)}{24}+\frac{32h^5f^{(5)}(x_i)}{120}+\dots$
#
# que podem ser usadas para aproximar a derivada utilizando mais pontos, com isso, a precisão aumenta mas a quantidade de cálculo necessário também aumenta. Fazendo
#
# $$f(x_{i-2}) - 8f(x_{i-1}) + 8f(x_{i+1}) - f(x_{i+2}) = 12hf^{\prime}(x_i) - \frac{48h^5f'''''(x_i)}{120}$$
#
# podemos escrever:
#
# $$ f^{\prime}(x_i) = \frac{f(x_{i-2}) - 8f(x_{i-1}) + 8f(x_{i-1}) - f(x_{i+2})}{12h} + O(h^4)$$
#
# ou
#
# $$ f^{\prime}(x_i) \approx \frac{f(x_{i-2}) - 8f(x_{i-1}) + 8f(x_{i-1}) - f(x_{i+2})}{12h}$$
#
# Essa fórmula é melhor do que a de diferenças finitas centrais mas requer o dobro de cálculo.

# %% [markdown]
# **Exemplo 9.4:** Sabemos que a derivada primeira de $f(x)=sen(x)$ é $f'(x)=cos(x)$. Vamos calcular as derivadas numericamente usando 2 e 4 pontos em torno de $x_i$ em um conjunto de 11 pontos de discretização do intervalo $[0, 2\pi]$ e comparar os gráficos e os erros médios.

# %%
# criando uma lista de pontos para o gráfico de cos(x)
x = np.linspace(0, 2*np.pi, 61)
cosx = np.cos(x)

xi = np.linspace(0, 2*np.pi, 11)
h=(xi[-1]-xi[0])/(len(xi)-1)
f = lambda x: np.sin(x)

# calculando as derivadas numéricas com 2 pontos
dxi2 = (f(xi[2:])-f(xi[0:-2]))/(2*h)

# calculando as derivadas numéricas com 4 pontos 
dxi4 = (f(xi[0:-4])-8*f(xi[1:-3])+8*f(xi[3:-1])-f(xi[4:]))/(12*h)

plt.plot(x,np.cos(x), 
         xi[1:-1], dxi2, '--',
         xi[2:-2], dxi4, '-.',
         color = 'k', lw=1)
plt.grid()

err2 = np.sum(abs(dxi2-np.cos(xi[1:-1])))/len(dxi2)
err4 = np.sum(abs(dxi4-np.cos(xi[2:-2])))/len(dxi4)

print('Erro médio 2 pontos:',err2)
print('Erro médio 4 pontos:',err4)
# Out:
# Erro médio 2 pontos: 0.039223489962551386
# Erro médio 4 pontos: 0.0027289966424816547

# %% [markdown]
# #### 9.3 Derivada de 2ª ordem em uma variável
#
# Da mesma forma que a derivada primeira pode ser aproximada em termos da variação da função em dois pontos, a derivada segunda pode ser aproximada em termos da variação na derivada primeira em dois pontos. Por exemplo, considerando as expanções em série de Taylor de $f$ em torno de $x_i$ e calculando a junção em $x_{i-1}$ e $x_{i+1}$ obtemos:

# %% [markdown]
# $$f(x_{i-1}) = f(x_i) - hf'(x_i) + \frac{h^2f''(x_i)}{2} - \frac{h^3f'''(x_i)}{6} + \dots$$
#
# e
#
# $$f(x_{i+1}) = f(x_i) + hf'(x_i) + \frac{h^2f''(x_i)}{2} + \frac{h^3f'''(x_i)}{6} + \dots$$
#
# Somando as duas equações acima obtemos:
#
# $$f(x_{i-1}) + f(x_{i+1}) = 2f(x_i) + h^2f''(x_i) + \frac{h^4f''''(x_i)}{24} + \dots$$
#
# que, desprezando os termos com derivadas de 4ª ordem ou maiores, nos dá a seguinte aproximação para a derivada segunda:
#
#
# $$ f''(x_i) \approx \frac{f(x_{i+1}) - 2f(x_i) + f(x_{i-1})}{h^2}$$

# %% [markdown]
# **Exemplo 9.5:** Sabemos que a derivada segunda de $f(x)=sen(x)$ é $f''(x)=-sen(x)$. Vamos calcular as derivadas numericamente usando 2 pontos em torno de $x_i$  em um conjunto de 21 pontos de discretização do intervalo $[0, 2\pi]$ e comparar os gráficos e os erros médios.

# %%
# criando uma lista de pontos para o gráfico de cos(x)
x = np.linspace(0, 2*np.pi, 61)
cosx = np.cos(x)

xi = np.linspace(0, 2*np.pi, 21)
h=(xi[-1]-xi[0])/(len(xi)-1)
f = lambda x: np.sin(x)

# calculando as derivadas 2ªs numéricas com 2 pontos
dxi2 = (f(xi[2:])-2*f(xi[1:-1])+f(xi[0:-2]))/(h**2)

plt.plot(x,-np.sin(x), '-',
         xi[1:-1], dxi2, '--',
         color='k', linewidth=1)
plt.grid()

# %% [markdown]
# **Exemplo 9.6:** A derivada de $f(x)=ln(x)$ é $f'(x)=1/x$. Vamos obter as aproximações para $f'(x)$ usando a função `numpy.gradient`.

# %%
# criando uma lista de pontos para o gráfico de ln(x)
x = np.linspace(0.1, 1.0)

xi = np.linspace(0.1, 1.0, 21)
h=(xi[-1]-xi[0])/(len(xi)-1)
f = lambda x: np.log(x)

# calculando as derivadas numéricas com 2 pontos
dxi2 = np.gradient(f(xi),xi)

plt.plot(x,1/x, '-k', alpha=0.5)
plt.plot(xi, dxi2, ':k')
plt.grid()

# %% [markdown]
# **Exemplo 9.7:** (Adaptado de Bourden & Faires) Em um circuito de voltagem impressa $\varepsilon(t)$ e indutância $L$, a primeira lei de Kirchhoff fornece a relação
#
# $$\varepsilon(t) = L \frac{di}{dt} + Ri$$
#
# Onde $R$ é a resistência do circuito e $i$ é a corrente. Suponha que alguns valores de corrente em função do tempo tenham sido medidos e os resultados são mostrados abaixo
#
# t   | 1,00 | 1,01 | 1,02 | 1,03 | 1,04 |
# ----|------|------|------|------|------|
# i   | 3,10 | 3,12 | 3,14 | 3,18 | 3,24 |
#
# onde $t$ é medido em segundos, $i$ está dado em ampères, a indutância $L$ é um valor constante de 0,98 henry e a resistência é de 0,142 ohm. Aproxime o valor da voltagem $\varepsilon(t)$ quando $t=$1,00, 1,01, 1,02, 1,03 e 1,04.

# %%
i = np.array([3.10, 3.12, 3.14, 3.18, 3.24])
t = np.array([1.00, 1.01, 1.02, 1.03, 1.04])
L = 0.98
R = 0.142
eps = L*(np.gradient(i,t)) + R*i
print(eps)
# Out:
# [2.4002  2.40304 3.38588 5.35156 6.34008]

# %% [markdown]
# **Exemplo 9.8:** A posição $s$ de um automóvel se locomovendo em linha reta em uma estrada é mostrada na tabela abaixo para diversos instantes de tempo. Use esses dados para estimar a velocidade e a aceleração do carro entre 0 e 13 segundos.
#
# t(s):| 0 | 3 | 5 | 8 | 10| 13|
# -----|---|---|---|---|---|---|
# s(m):| 0 |225|383|623|742|993|

# %%
t = np.array([0.,3.,5.,8.,10.,13.])
s = np.array([0., 225., 383., 623., 742., 993.])

v = np.gradient(s,t)
print (f' Velocidade(m/s): {np.round(v,2)}')

a = np.gradient(v,t)
print (f' Aceleração(m/s²)$: {np.round(a,2)}')
# Out:
#  Velocidade(m/s): [75.   77.4  79.4  67.7  69.17 83.67]
#  Aceleração(m/s²)$: [ 0.8   0.92 -0.96 -1.12  2.37  4.83]

# %% [markdown]
# #### Exercícios:
# Utilize diferentes fórmulas de aproximação para obter as derivadas numérica das funções listadas abaixo e construir os gráficos. Compare com o gráfico da derivada obtida analiticamente. Calcule o erro quadrático médio.
#
# a) $f(x)=e^{2x}$
#
# b) $f(x)=x ln(x)$
#
# c) $f(x)=x cos(x)-x^2sen(x)$
#
# d) $f(x)=2ln(x)^2+3sen(x)$
#
# e) $f(x)=2^xsen(x)$
#
# f) $f(x)=x^2e^x$
